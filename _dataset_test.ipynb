# %%
from src.dataset.tornado_reflectivity import TornadoReflectivityDataset


dataset = TornadoReflectivityDataset(split="train")
# Out:
# 🌪️ Loading tornado events from cache:  82%|████████▏ | 1745/2141 [00:01<00:00, 1472.95it/s]
# Error: 20240419_1913_1913_EF0 could not be loaded from cache...
# ...
# 100%|██████████| 1819/1819 [00:00<00:00, 53537.29it/s]

# %%
item = dataset[615]
src = item['source'].numpy()
tar = item['target'].numpy()

# plot src/tar side by side, both have dims of 224, 224
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 2, figsize=(10, 5), dpi=600)
ax[0].imshow(src)
ax[0].set_title("Source")
ax[1].imshow(tar)
ax[1].set_title("Target")
plt.show()
